# %% [markdown]
# <a href="https://colab.research.google.com/github/Tahabaig044/Project_4/blob/main/assignment_1_to_6/Project_5_hangman_python_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def choose_word():
    words = [
        # Daily-use words
        "apple", "banana", "grape", "orange", "strawberry", "chocolate", "coffee", "laptop", "mobile", "bottle",
        "pencil", "notebook", "garden", "window", "kitchen", "bedroom", "mirror", "blanket", "cushion", "guitar",
        "television", "vacation", "sunshine", "rainbow", "mountain", "ocean", "beach", "library", "cinema", "holiday",

        # Programming-related words
        "python", "javascript", "typescript", "compiler", "debugging", "variable", "function", "algorithm",
        "framework", "database", "frontend", "backend", "fullstack", "developer", "cybersecurity", "authentication",
        "authorization", "network", "protocol", "software", "hardware", "encryption", "artificial", "intelligence",
        "machine", "learning", "server", "client", "internet", "computer"
    ]
    return random.choice(words).lower()

def display_word(word, guessed_letters):
    return " ".join(letter if letter in guessed_letters else "_" for letter in word)

def hangman():
    word = choose_word()
    guessed_letters = set()
    attempts = 6  # Max incorrect guesses

    print("🎯 Welcome to Hangman! 🎯")

    while attempts > 0:
        print("\nWord:", display_word(word, guessed_letters))
        print(f"Attempts left: {attempts}")
        print(f"Guessed letters: {', '.join(sorted(guessed_letters)) if guessed_letters else 'None'}")

        guess = input("Guess a letter: ").lower()

        if len(guess) != 1 or not guess.isalpha():
            print("⚠️ Please enter a single valid letter.")
            continue

        if guess in guessed_letters:
            print("⏳ You've already guessed that letter!")
            continue

        guessed_letters.add(guess)

        if guess in word:
            print("✅ Good guess!")
        else:
            print("❌ Wrong guess!")
            attempts -= 1

        if all(letter in guessed_letters for letter in word):
            print(f"\n🎉 Congratulations! You guessed the word: {word} 🎉")
            break
    else:
        print(f"\n💀 Game Over! The word was: {word}")

# Run the game
hangman()
# Out:
# 🎯 Welcome to Hangman! 🎯
#
# Word: _ _ _ _ _ _ _ _
# Attempts left: 6
# Guessed letters: None
# Guess a letter: a
# ✅ Good guess!
#
# Word: _ a _ _ a _ _ _
# Attempts left: 6
# Guessed letters: a
# Guess a letter: e
# ✅ Good guess!
#
# Word: _ a _ _ a _ _ e
# Attempts left: 6
# Guessed letters: a, e
# Guess a letter: c
# ❌ Wrong guess!
#
# Word: _ a _ _ a _ _ e
# Attempts left: 5
# Guessed letters: a, c, e
# Guess a letter: i
# ✅ Good guess!
#
# Word: _ a _ i a _ _ e
# Attempts left: 5
# Guessed letters: a, c, e, i
# Guess a letter: c
# ⏳ You've already guessed that letter!
#
# Word: _ a _ i a _ _ e
# Attempts left: 5
# Guessed letters: a, c, e, i
# Guess a letter: n
# ❌ Wrong guess!
#
# Word: _ a _ i a _ _ e
# Attempts left: 4
# Guessed letters: a, c, e, i, n
# Guess a letter: o
# ❌ Wrong guess!
#
# Word: _ a _ i a _ _ e
# Attempts left: 3
# Guessed letters: a, c, e, i, n, o
# Guess a letter: g
# ❌ Wrong guess!
#
# Word: _ a _ i a _ _ e
# Attempts left: 2
# Guessed letters: a, c, e, g, i, n, o
# Guess a letter: s
# ❌ Wrong guess!
#
# Word: _ a _ i a _ _ e
# Attempts left: 1
# Guessed letters: a, c, e, g, i, n, o, s
# Guess a letter: l
# ✅ Good guess!
#
# Word: _ a _ i a _ l e
# Attempts left: 1
# Guessed letters: a, c, e, g, i, l, n, o, s
# Guess a letter: b
# ✅ Good guess!
#
# Word: _ a _ i a b l e
# Attempts left: 1
# Guessed letters: a, b, c, e, g, i, l, n, o, s
# Guess a letter: v
# ✅ Good guess!
#
# Word: v a _ i a b l e
# Attempts left: 1
# Guessed letters: a, b, c, e, g, i, l, n, o, s, v
# Guess a letter: r
# ✅ Good guess!
#
# 🎉 Congratulations! You guessed the word: variable 🎉
